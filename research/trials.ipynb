# %%
pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in /Users/enitan/Desktop/Projects/Chest-Disease-Classification-MLOPs/venv/lib/python3.13/site-packages (from kagglehub) (25.0)
# Collecting pyyaml (from kagglehub)
#   Downloading pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Requirement already satisfied: requests in /Users/enitan/Desktop/Projects/Chest-Disease-Classification-MLOPs/venv/lib/python3.13/site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in /Users/enitan/Desktop/Projects/Chest-Disease-Classification-MLOPs/venv/lib/python3.13/site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/enitan/Desktop/Projects/Chest-Disease-Classification-MLOPs/venv/lib/python3.13/site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/enitan/Desktop/Projects/Chest-Disease-Classification-MLOPs/venv/lib/python3.13/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/enitan/Desktop/Projects/Chest-Disease-Classification-MLOPs/venv/lib/python3.13/site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/enitan/Desktop/Projects/Chest-Disease-Classification-MLOPs/venv/lib/python3.13/site-packages (from requests->kagglehub) (2025.11.12)
# Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Downloading pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Installing collected packages: pyyaml, kagglehub
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kagglehub]
# Successfully installed kagglehub-0.3.13 pyyaml-6.0.3
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mohamedhanyyy/chest-ctscan-images")

print("data/", path)
# Out:
# data/ /Users/enitan/.cache/kagglehub/datasets/mohamedhanyyy/chest-ctscan-images/versions/1
